# %% [markdown]
# # This is the title in markdown
#
# for more information, check out [this link](https://medium.com/@mjspeck/presenting-code-using-jupyter-notebook-slides-a8a3c3b59d67)

# %% [markdown]
# ## This is a subslide
#
# Setting things up

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(0, 8, 1000)
y = np.sin(x)
plt.plot(x,y)
